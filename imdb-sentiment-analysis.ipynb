# %% [markdown]
# <a href="https://www.kaggle.com/code/kenza1996/imdb-sentiment-analysis?scriptVersionId=206612840" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# # My NLP project  using  1D  CNN

# %%
#import libraries
import numpy as np
import tensorflow as tf
import pandas as pd
from sklearn.model_selection import train_test_split
from keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras import models,layers
from tensorflow.keras.layers import Embedding, LSTM, Dense, Activation, Dropout
from tensorflow.keras.models import Sequential
from tensorflow.keras import regularizers

# %%
#load the DataFrame
data=pd.read_csv("/kaggle/input/imdb-reviews/IMDB Dataset.csv")
data.head(4)
# Out:
#                                               review sentiment
# 0  One of the other reviewers has mentioned that ...  positive
# 1  A wonderful little production. <br /><br />The...  positive
# 2  I thought this was a wonderful way to spend ti...  positive
# 3  Basically there's a family where a little boy ...  negative

# %%
# access the column labels of my DataFrame
data.columns
# Out:
# Index(['review', 'sentiment'], dtype='object')

# %%
## Separating features (X) and labels (y)
X = data['review'] 
X
# Out:
# 0        One of the other reviewers has mentioned that ...
# 1        A wonderful little production. <br /><br />The...
# 2        I thought this was a wonderful way to spend ti...
# 3        Basically there's a family where a little boy ...
# 4        Petter Mattei's "Love in the Time of Money" is...
#                                ...
# 49995    I thought this movie did a down right good job...
# 49996    Bad plot, bad dialogue, bad acting, idiotic di...
# 49997    I am a Catholic taught in parochial elementary...
# 49998    I'm going to have to disagree with the previou...
# 49999    No one expects the Star Trek movies to be high...
# Name: review, Length: 50000, dtype: object

# %%
## Separating features (X) and labels (y)
Y=data['sentiment']
Y
# Out:
# 0        positive
# 1        positive
# 2        positive
# 3        negative
# 4        positive
#            ...
# 49995    positive
# 49996    negative
# 49997    negative
# 49998    negative
# 49999    negative
# Name: sentiment, Length: 50000, dtype: object

# %%
# Converting categorical sentiment labels to numerical values for model training
data['sentiment'] = data['sentiment'].map({'positive': 1, 'negative':0})
Y = data.sentiment

# %%
# Splitting the dataset into training and testing sets
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# %%
# Tokenizing the text data to convert words into numerical sequences
tokenizer = Tokenizer(num_words=1000,
filters='!"#$%&()*+,-./:;<=>?@[\]^_`{"}~\t\n',lower=True, split=" ")
tokenizer.fit_on_texts(X_train)
X_train_seq = tokenizer.texts_to_sequences(X_train)
X_test_seq = tokenizer.texts_to_sequences(X_test)

# %%
# Padding sequences to ensure uniform length for model input
X_train_seq_trunc = pad_sequences(X_train_seq, maxlen=100)
X_test_seq_trunc = pad_sequences(X_test_seq, maxlen=100)

# %%
# Building a convolutional neural network (CNN) model for text classification
model = models.Sequential()
model.add(layers.Embedding(len(tokenizer.index_word), 8, input_length=100))# Adding an embedding layer to convert numerical sequences into dense vectors
model.add(layers.Convolution1D(16,4,activation='relu',input_shape=(100, 1)))
model.add(layers.AveragePooling1D())
model.add(layers.Convolution1D(32,4,activation='relu'))
model.add(layers.AveragePooling1D())
model.add(layers.Flatten())
model.add(layers.Dense(1, activation='sigmoid'))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 100, 8)            898456
#
#  conv1d (Conv1D)             (None, 97, 16)            528
#
#  average_pooling1d (Average  (None, 48, 16)            0
#  Pooling1D)
#
#  conv1d_1 (Conv1D)           (None, 45, 32)            2080
#
#  average_pooling1d_1 (Avera  (None, 22, 32)            0
#  gePooling1D)
#
#  flatten (Flatten)           (None, 704)               0
#
#  dense (Dense)               (None, 1)                 705
#
# =================================================================
# Total params: 901769 (3.44 MB)
# Trainable params: 901769 (3.44 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Compiling the CNN model for text classification
model.compile(optimizer='adam',loss=tf.keras.losses.BinaryCrossentropy(),
                  metrics=[tf.keras.metrics.BinaryAccuracy()])

# %%
# Training the CNN model for text classification
model.fit(x=X_train_seq_trunc,y=Y_train,batch_size=128,
              epochs=15,validation_data=(X_test_seq_trunc,Y_test))
# Out:
# Epoch 1/15
# 313/313 [==============================] - 7s 17ms/step - loss: 0.5233 - binary_accuracy: 0.7117 - val_loss: 0.3844 - val_binary_accuracy: 0.8249
# Epoch 2/15
# 313/313 [==============================] - 5s 16ms/step - loss: 0.3814 - binary_accuracy: 0.8284 - val_loss: 0.3714 - val_binary_accuracy: 0.8290
# Epoch 3/15
# 313/313 [==============================] - 5s 16ms/step - loss: 0.3656 - binary_accuracy: 0.8366 - val_loss: 0.3588 - val_binary_accuracy: 0.8372
# Epoch 4/15
# 313/313 [==============================] - 5s 15ms/step - loss: 0.3564 - binary_accuracy: 0.8432 - val_loss: 0.3608 - val_binary_accuracy: 0.8384
# Epoch 5/15
# 313/313 [==============================] - 5s 15ms/step - loss: 0.3480 - binary_accuracy: 0.8458 - val_loss: 0.3496 - val_binary_accuracy: 0.8439
# Epoch 6/15
# 313/313 [==============================] - 5s 15ms/step - loss: 0.3413 - binary_accuracy: 0.8494 - val_loss: 0.3499 - val_binary_accuracy: 0.8440
# Epoch 7/15
# 313/313 [==============================] - 5s 15ms/step - loss: 0.3361 - binary_accuracy: 0.8516 - val_loss: 0.3531 - val_binary_accuracy: 0.8412
# Epoch 8/15
# 313/313 [==============================] - 5s 15ms/step - loss: 0.3299 - binary_accuracy: 0.8557 - val_loss: 0.3428 - val_binary_accuracy: 0.8449
# Epoch 9/15
# 313/313 [==============================] - 5s 16ms/step - loss: 0.3260 - binary_accuracy: 0.8571 - val_loss: 0.3429 - val_binary_accuracy: 0.8462
# Epoch 10/15
# 313/313 [==============================] - 5s 17ms/step - loss: 0.3219 - binary_accuracy: 0.8595 - val_loss: 0.3431 - val_binary_accuracy: 0.8448
# Epoch 11/15
# 313/313 [==============================] - 5s 16ms/step - loss: 0.3163 - binary_accuracy: 0.8616 - val_loss: 0.3425 - val_binary_accuracy: 0.8458
# Epoch 12/15
# 313/313 [==============================] - 5s 16ms/step - loss: 0.3122 - binary_accuracy: 0.8646 - val_loss: 0.3440 - val_binary_accuracy: 0.8463
# Epoch 13/15
# 313/313 [==============================] - 5s 15ms/step - loss: 0.3069 - binary_accuracy: 0.8669 - val_loss: 0.3446 - val_binary_accuracy: 0.8468
# Epoch 14/15
# 313/313 [==============================] - 5s 16ms/step - loss: 0.3025 - binary_accuracy: 0.8710 - val_loss: 0.3443 - val_binary_accuracy: 0.8460
# Epoch 15/15
# 313/313 [==============================] - 5s 16ms/step - loss: 0.2973 - binary_accuracy: 0.8719 - val_loss: 0.3461 - val_binary_accuracy: 0.8441

# %% [markdown]
# # RNN LSTM

# %%
# Building a convolutional neural network (CNN) model for text classification
model2 = models.Sequential()
model2.add(layers.Embedding(len(tokenizer.index_word), 8, input_length=100))# Adding an embedding layer to convert numerical sequences into dense vectors
model2.add(layers.LSTM(64))
model2.add(layers.Dense(256))
model2.add(layers.Activation('relu'))
model2.add(layers.Dropout(0.5))
model2.add(layers.Dense(1, name='out_layer'))
model2.add(layers.Activation('sigmoid'))
model2.compile(loss = 'binary_crossentropy', optimizer='adam',\
               metrics = ['accuracy'])
print(model2.summary())
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_1 (Embedding)     (None, 100, 8)            898456
#
#  lstm (LSTM)                 (None, 64)                18688
#
#  dense_1 (Dense)             (None, 256)               16640
#
#  activation (Activation)     (None, 256)               0
#
#  dropout (Dropout)           (None, 256)               0
#
#  out_layer (Dense)           (None, 1)                 257
#
#  activation_1 (Activation)   (None, 1)                 0
#
# =================================================================
# Total params: 934041 (3.56 MB)
# Trainable params: 934041 (3.56 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None

# %%
# Training the CNN model for text classification
model2.fit(x=X_train_seq_trunc,y=Y_train,batch_size=30,
              epochs=15,validation_data=(X_test_seq_trunc,Y_test))
# Out:
# Epoch 1/15
# 1334/1334 [==============================] - 75s 54ms/step - loss: 0.4242 - accuracy: 0.8005 - val_loss: 0.3860 - val_accuracy: 0.8331
# Epoch 2/15
# 1334/1334 [==============================] - 72s 54ms/step - loss: 0.3660 - accuracy: 0.8411 - val_loss: 0.3541 - val_accuracy: 0.8429
# Epoch 3/15
# 1334/1334 [==============================] - 71s 53ms/step - loss: 0.3515 - accuracy: 0.8471 - val_loss: 0.3563 - val_accuracy: 0.8468
# Epoch 4/15
# 1334/1334 [==============================] - 71s 53ms/step - loss: 0.3384 - accuracy: 0.8531 - val_loss: 0.3422 - val_accuracy: 0.8479
# Epoch 5/15
# 1334/1334 [==============================] - 73s 54ms/step - loss: 0.3282 - accuracy: 0.8589 - val_loss: 0.3389 - val_accuracy: 0.8468
# Epoch 6/15
# 1334/1334 [==============================] - 73s 54ms/step - loss: 0.3188 - accuracy: 0.8608 - val_loss: 0.3496 - val_accuracy: 0.8412
# Epoch 7/15
# 1334/1334 [==============================] - 78s 59ms/step - loss: 0.3062 - accuracy: 0.8677 - val_loss: 0.3228 - val_accuracy: 0.8574
# Epoch 8/15
# 1334/1334 [==============================] - 74s 55ms/step - loss: 0.2964 - accuracy: 0.8737 - val_loss: 0.3239 - val_accuracy: 0.8567
# Epoch 9/15
# 1334/1334 [==============================] - 74s 55ms/step - loss: 0.2861 - accuracy: 0.8787 - val_loss: 0.3613 - val_accuracy: 0.8511
# Epoch 10/15
# 1334/1334 [==============================] - 73s 55ms/step - loss: 0.2766 - accuracy: 0.8840 - val_loss: 0.3356 - val_accuracy: 0.8634
# Epoch 11/15
# 1334/1334 [==============================] - 75s 56ms/step - loss: 0.2688 - accuracy: 0.8891 - val_loss: 0.3168 - val_accuracy: 0.8607
# Epoch 12/15
# 1334/1334 [==============================] - 73s 54ms/step - loss: 0.2607 - accuracy: 0.8921 - val_loss: 0.3287 - val_accuracy: 0.8629
# Epoch 13/15
# 1334/1334 [==============================] - 73s 55ms/step - loss: 0.2529 - accuracy: 0.8959 - val_loss: 0.3333 - val_accuracy: 0.8568
# Epoch 14/15
# 1334/1334 [==============================] - 73s 54ms/step - loss: 0.2454 - accuracy: 0.8991 - val_loss: 0.3363 - val_accuracy: 0.8514
# Epoch 15/15
# 1334/1334 [==============================] - 74s 56ms/step - loss: 0.2390 - accuracy: 0.9033 - val_loss: 0.3339 - val_accuracy: 0.8544

# %% [markdown]
# # pre-trained GloVe word+RNN LSTM

# %%
# Load pre-trained GloVe word embeddings
embedding_dim = 100  # Set this based on the dimensions of the GloVe file you downloaded
embedding_matrix = np.zeros((len(tokenizer.word_index) + 1, embedding_dim))

glove_file = "/kaggle/input/glove-6b-100d/glove.6B.100d.txt"  # Replace with the actual path to your GloVe file
with open(glove_file, encoding="utf8") as f:
    for line in f:
        values = line.split()
        word = values[0]
        if word in tokenizer.word_index:
            embedding_matrix[tokenizer.word_index[word]] = np.array(values[1:], dtype="float32")

# %%
# Building a convolutional neural network (CNN) model for text classification with pre-trained word embeddings
model = Sequential()
model.add(Embedding(input_dim=len(tokenizer.word_index) + 1, output_dim=embedding_dim, weights=[embedding_matrix],
                    input_length=100, trainable=False))  # Set trainable to True if you want to fine-tune embeddings
model.add(LSTM(64, kernel_regularizer=regularizers.l2(0.01)))  # Adjust regularization as needed
model.add(Dense(256))
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(1, name='out_layer'))
model.add(Activation('sigmoid'))
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
print(model.summary())
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_2 (Embedding)     (None, 100, 100)          11230800
#
#  lstm_1 (LSTM)               (None, 64)                42240
#
#  dense_2 (Dense)             (None, 256)               16640
#
#  activation_2 (Activation)   (None, 256)               0
#
#  dropout_1 (Dropout)         (None, 256)               0
#
#  out_layer (Dense)           (None, 1)                 257
#
#  activation_3 (Activation)   (None, 1)                 0
#
# =================================================================
# Total params: 11289937 (43.07 MB)
# Trainable params: 59137 (231.00 KB)
# Non-trainable params: 11230800 (42.84 MB)
# _________________________________________________________________
# None

# %%
# Training the CNN model for text classification
model.fit(x=X_train_seq_trunc, y=Y_train, batch_size=128, epochs=30, validation_data=(X_test_seq_trunc, Y_test))
# Out:
# Epoch 1/30
# 313/313 [==============================] - 41s 123ms/step - loss: 0.8322 - accuracy: 0.6710 - val_loss: 0.5941 - val_accuracy: 0.7427
# Epoch 2/30
# 313/313 [==============================] - 37s 119ms/step - loss: 0.5635 - accuracy: 0.7537 - val_loss: 0.5511 - val_accuracy: 0.7580
# Epoch 3/30
# 313/313 [==============================] - 37s 119ms/step - loss: 0.5293 - accuracy: 0.7701 - val_loss: 0.5106 - val_accuracy: 0.7794
# Epoch 4/30
# 313/313 [==============================] - 37s 119ms/step - loss: 0.5131 - accuracy: 0.7771 - val_loss: 0.5135 - val_accuracy: 0.7790
# Epoch 5/30
# 313/313 [==============================] - 37s 119ms/step - loss: 0.4897 - accuracy: 0.7922 - val_loss: 0.4683 - val_accuracy: 0.8008
# Epoch 6/30
# 313/313 [==============================] - 37s 120ms/step - loss: 0.4774 - accuracy: 0.7975 - val_loss: 0.4606 - val_accuracy: 0.8066
# Epoch 7/30
# 313/313 [==============================] - 38s 121ms/step - loss: 0.4707 - accuracy: 0.7977 - val_loss: 0.4599 - val_accuracy: 0.8053
# Epoch 8/30
# 313/313 [==============================] - 37s 119ms/step - loss: 0.4634 - accuracy: 0.8027 - val_loss: 0.4490 - val_accuracy: 0.8121
# Epoch 9/30
# 313/313 [==============================] - 37s 118ms/step - loss: 0.4544 - accuracy: 0.8055 - val_loss: 0.4468 - val_accuracy: 0.8100
# Epoch 10/30
# 313/313 [==============================] - 37s 118ms/step - loss: 0.4484 - accuracy: 0.8105 - val_loss: 0.4654 - val_accuracy: 0.7937
# Epoch 11/30
# 313/313 [==============================] - 38s 120ms/step - loss: 0.4487 - accuracy: 0.8077 - val_loss: 0.4659 - val_accuracy: 0.8002
# Epoch 12/30
# 313/313 [==============================] - 38s 121ms/step - loss: 0.4397 - accuracy: 0.8126 - val_loss: 0.4279 - val_accuracy: 0.8178
# Epoch 13/30
# 313/313 [==============================] - 38s 122ms/step - loss: 0.4380 - accuracy: 0.8148 - val_loss: 0.4246 - val_accuracy: 0.8199
# Epoch 14/30
# 313/313 [==============================] - 38s 122ms/step - loss: 0.4359 - accuracy: 0.8146 - val_loss: 0.4831 - val_accuracy: 0.7967
# Epoch 15/30
# 313/313 [==============================] - 39s 124ms/step - loss: 0.4324 - accuracy: 0.8163 - val_loss: 0.4154 - val_accuracy: 0.8224
# Epoch 16/30
# 313/313 [==============================] - 38s 120ms/step - loss: 0.4314 - accuracy: 0.8170 - val_loss: 0.4200 - val_accuracy: 0.8219
# Epoch 17/30
# 313/313 [==============================] - 38s 121ms/step - loss: 0.4263 - accuracy: 0.8173 - val_loss: 0.4170 - val_accuracy: 0.8229
# Epoch 18/30
# 313/313 [==============================] - 37s 119ms/step - loss: 0.4234 - accuracy: 0.8200 - val_loss: 0.4129 - val_accuracy: 0.8277
# Epoch 19/30
# 313/313 [==============================] - 37s 119ms/step - loss: 0.4214 - accuracy: 0.8223 - val_loss: 0.4130 - val_accuracy: 0.8246
# Epoch 20/30
# 313/313 [==============================] - 37s 118ms/step - loss: 0.4212 - accuracy: 0.8231 - val_loss: 0.4336 - val_accuracy: 0.8097
# Epoch 21/30
# 313/313 [==============================] - 38s 120ms/step - loss: 0.4160 - accuracy: 0.8232 - val_loss: 0.4074 - val_accuracy: 0.8263
# Epoch 22/30
# 313/313 [==============================] - 37s 119ms/step - loss: 0.4183 - accuracy: 0.8235 - val_loss: 0.4144 - val_accuracy: 0.8245
# Epoch 23/30
# 313/313 [==============================] - 37s 119ms/step - loss: 0.4175 - accuracy: 0.8240 - val_loss: 0.4131 - val_accuracy: 0.8244
# Epoch 24/30
# 313/313 [==============================] - 38s 122ms/step - loss: 0.4155 - accuracy: 0.8242 - val_loss: 0.4116 - val_accuracy: 0.8222
# Epoch 25/30
# 313/313 [==============================] - 37s 119ms/step - loss: 0.4178 - accuracy: 0.8238 - val_loss: 0.4101 - val_accuracy: 0.8254
# Epoch 26/30
# 313/313 [==============================] - 37s 119ms/step - loss: 0.4122 - accuracy: 0.8253 - val_loss: 0.4394 - val_accuracy: 0.8062
# Epoch 27/30
# 313/313 [==============================] - 37s 120ms/step - loss: 0.4084 - accuracy: 0.8300 - val_loss: 0.3974 - val_accuracy: 0.8340
# Epoch 28/30
# 313/313 [==============================] - 38s 121ms/step - loss: 0.4135 - accuracy: 0.8236 - val_loss: 0.4135 - val_accuracy: 0.8269
# Epoch 29/30
# 313/313 [==============================] - 37s 120ms/step - loss: 0.4029 - accuracy: 0.8304 - val_loss: 0.3985 - val_accuracy: 0.8342
# Epoch 30/30
# 313/313 [==============================] - 39s 124ms/step - loss: 0.4071 - accuracy: 0.8290 - val_loss: 0.4215 - val_accuracy: 0.8157
